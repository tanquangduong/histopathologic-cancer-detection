# %%
import os
import shutil
import opendatasets as od
import pandas as pd
import numpy as np
from PIL import Image

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
cancer_labels = pd.read_csv('datasets/selected_image_labels.csv')
cancer_labels = cancer_labels[['id', 'label']]
cancer_labels.head()
# Out:
#                                          id  label
# 0  b05fff3bc03c92a194575bd04a810f34fe85bd3a      0
# 1  880115b62d875c6f95857bd6cb384edb7b3f230b      0
# 2  b8bfed7bf5f210d34daedcfb3d68f2acc65881f9      0
# 3  a18691b54470f01b53a99b3a30821dea4fa1b3eb      1
# 4  19e3827697472fa4103428105042176f5b400dd8      1

# %%
cancer_labels.shape
# Out:
# (10000, 2)

# %%
train_image = os.listdir("datasets/cancer_train_dataset/")

# %%
fig = plt.figure(figsize=(25, 6))
for idx, img in enumerate(np.random.choice(train_image, 20)):
    ax = fig.add_subplot(2, 20//2, idx+1, xticks=[], yticks=[])
    im = Image.open("./datasets/cancer_train_dataset/" + img)
    plt.imshow(im)
    lab = cancer_labels.loc[cancer_labels['id'] == img.split('.')[0], 'label'].values[0]
    ax.set_title(f'Label: {lab}')
